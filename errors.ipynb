# %%
using JLD2
using LensFactory

# %%
# Read samples
sample = jldopen("./SMACS0723/SMACS0723_sample.jld2")

# Read data
model  = sample["model"]
chains = sample["chains"]
logL   = sample["logL"]
# Out:
# 1001×1 Matrix{Float64}:
#  -33.57381460130607
#  -35.931400504424346
#  -30.31245802218698
#  -25.205722984538863
#  -31.526592187429657
#  -36.06559150260801
#  -28.70182060602943
#  -27.604367839362645
#  -33.25551597160878
#  -27.045601277818147
#    ⋮
#  -29.8246998757551
#  -40.557341866747365
#  -32.76878515831891
#  -37.57411522374773
#  -31.623576337218402
#  -36.11022358592838
#  -25.822659482529737
#  -32.38348734506451
#  -25.079973468121985

# %%
# Get best-fit magnification at a given (RA, Dec)
best_model, _ = LensModel.get_best_model(model; mcmc_chains=chains, mcmc_logL=logL)
dxx, dyy, dxy = LensModel.get_jacobian(best_model, 110.8246996, -73.4564175; reference=(model.observation.reference[1], model.observation.reference[2]))
# Out:
# 1.3120059165331543
